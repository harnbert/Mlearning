# %% [markdown]
# **la régression linéaire**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# La régression linéaire avec une seule variable

# %% [markdown]
# Probléme

# %%
data=pd.read_csv('../input/ex1data1.csv')
print(f'TRAINING DATASET SHAPE : {data.shape[0]} X {data.shape[1]}')
data.head()
# Out:
# TRAINING DATASET SHAPE : 97 X 2
#    population   profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %% [markdown]
# **La représentation de note data**

# %% [markdown]
# Avant de commencer notre traitement,on va plotter notre data

# %%
sns.scatterplot(x='population',y='profit',data=data,label='Training Data',color='red',marker='x');
